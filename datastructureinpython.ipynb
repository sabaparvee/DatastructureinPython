# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Linked list

# %%
class Node:
    def __init__(self,value):
        self.data=value
        self.next=None

# %%
class LinkedList:
    def __init__(self):
        self.head=None
        self.n=0
    def __len__(self):
        return self.n
    def insert_head(self,value):
        new_node=Node(value)
        new_node.next=self.head
        self.head=new_node
        self.n=self.n+1
    def __str__(self):
        curr=self.head
        result=' '
        while curr!=None:
            result=result+str(curr.data)+'->'
            curr=curr.next
        return result[:-2]
    
    def append(self,value):
        new_node=Node(value)
        if self.head==None:
            self.head=new_node
            self.n=self.n+1
            return
        curr=self.head
        while curr.next!=None:
            curr=curr.next
        curr.next=new_node
        self.n=self.n+1
    # Inserting element after the given element    
    def insert_after(self,after,value):
        new_node=Node(value)
        curr=self.head
        while curr!=None:
            if curr.data==after:
                break
        if curr!=None:
            new_node.next=curr.next
            curr.next=new_node
            self.n=self.n+1
        else:
            return "item not found"
        
        #clear all linked list
        def clear(self):
            self.head=None
            self.n=0
            
    #deleting one element from linked list
    def delete_head(self):
        if self.head==None:
            return 'empty ll'
        self.head=self.head.next
        self.n=self.n-1
        
    #delete from tail called pop
    def pop(self):
        if self.head==None:
            return 'Empty linked list'
        curr=self.head
        while curr.next.next!=None:
            curr=curr.next
        curr.next=None
        self.n=self.n-1
        
    # Removing particular element from the linked list
    def remove(self,value):
        if self.head==None:
            return "empty ll"
        if self.head.data==value:
            return self.delete_head()
        curr=self.head
        while curr.next!=None:
            if curr.next.data==value:
                break
            curr=curr.next
        if curr.next==None:
            return 'Not Found'
        else:
            curr.next=curr.next.next
            self.n=self.n-1
            
      # Searching element in linked list and return position
    def search(self,item):
        curr=self.head
        pos=0
        while curr!=None:
            if curr.data==item:
                return pos
            curr=curr.next
            pos=pos+1
            
        return 'item not found'
    #Searching element in linked list by index value
    def __getitem__(self,index):
        curr=self.head
        pos=0
        while curr!=None:
            if pos==index:
                return curr.data
            curr=curr.next
            pos=pos+1
        return 'Index Error'

# %%
l=LinkedList()

# %%
l.insert_head(4)
l.insert_head(8)

# %%
l.insert_after(8,3)

# %%
print(l)
# Out:
#  8->3->4

# %%
l.delete_head()

# %%
print(l)
# Out:
#  3->4

# %%
l.pop()

# %%
print(l)
# Out:
#  3

# %%
l.insert_head(5)
l.insert_head(6)
l.insert_head(7)

# %%
print(l)
# Out:
#  7->6->5->3

# %%
l.search(5)
# Out:
# 2

# %% [markdown]
# # Stack

# %%
class Node:
    def __init__(self,value):
        self.data=value
        self.next=None

# %%
class stack:
    def __init__(self):
        self.top=None
    def isempty(self):
        return self.top==None
    def push(self,value):
        new_node=Node(value)
        new_node.next=self.top
        self.top=new_node
    def traverse(self):
        temp=self.top
        while temp!=None:
            print(temp.data)
            temp=temp.next         
    def peek(self):
        if(self.isempty()):
            return "stack empty"
        else:
            return self.top.data
    def pop(self):
        if(self.isempty()):
            return "stack empty"
        else:
            data=self.top.data
            self.top=self.top.next
            return data

# %%
s=stack()

# %%
s.isempty()
# Out:
# True

# %%
s.push(2)

# %%
s.push(3)
s.push(5)
s.push(4)

# %%
s.traverse()
# Out:
# 4
# 5
# 3
# 2

# %%
s.pop()
# Out:
# 4

# %%
s.traverse()
# Out:
# 5
# 3
# 2

# %% [markdown]
# ### string reversal using stack

# %%
def reverse_string(text):
    s=stack()
    for i in text:
        s.push(i)
    res=" "
    while(not s.isempty()):
        res=res+s.pop()
    print(res)

# %%
reverse_string('hello')
# Out:
#  olleh

# %% [markdown]
# # Queue

# %%
class Node:
    def __init__(self,value):
        self.data=value
        self.next=None
class Queue:
    def __init__(self):
        self.front=None
        self.rear=None
        
    def enqueue(self,value):
        new_node=Node(value)
        if self.rear==None:
            self.front=new_node
            self.rear=self.front
        else:
            self.rear.next=new_node
            self.rear=new_node
            
    def dequeue(self):
        if self.front==None:
            return"empty"
        else:
            self.front=self.front.next
            
    def traverse(self):
        temp=self.front
        while temp!=None:
            print(temp.data, end=" ")
            temp=temp.next
    def is_empty(self):
        return self.front==None
    
    def size(self):
        temp=self.front
        
    def size(self):
        temp=self.front
        counter=0
        while temp!=None:
            counter+=1
            temp=temp.next
        return counter
    def front_item(self):
        if self.front==None:
            return "empty"
        else:
            return self.front.data
        
    def rear_item(self):
        if self.front==None:
            return "empty"
        else:
            return self.rear.data

# %%
q=Queue()
q.enqueue(4)

# %%
q.enqueue(5)
q.enqueue(7)
q.enqueue(1)
q.traverse()
# Out:
# 4 5 7 1

# %%
q.dequeue()

# %%
q.traverse()
# Out:
# 5 7 1

# %% [markdown]
# # Linear Search

# %%
def linear_search(arr,item):
    for i in range(len(arr)):
        if arr[i]==item:
            return i
    return -1

# %%
arr=[12,34,56,1,67,100,47,99]
linear_search(arr,121)
# Out:
# -1

# %%
linear_search(arr,100)
# Out:
# 5

# %% [markdown]
# Time complexity is O(N)

# %% [markdown]
# # Binary Search

# %%
def binary_search(arr, low, high, x):
 
    # Check base case
    if high >= low:
 
        mid = (high + low) // 2
 
        # If element is present at the middle itself
        if arr[mid] == x:
            return mid
 
        # If element is smaller than mid, then it can only
        # be present in left subarray
        elif arr[mid] > x:
            return binary_search(arr, low, mid - 1, x)
 
        # Else the element can only be present in right subarray
        else:
            return binary_search(arr, mid + 1, high, x)
 
    else:
        # Element is not present in the array
        return -1

# %%
arr=[12,34,56,46,57,68,80,99,100]
x=99
result=binary_search(arr,0,len(arr)-1,x)

# %%
result
# Out:
# 7

# %% [markdown]
# Time Complexity of Binary Search is O(logn)

# %% [markdown]
# ## Simple Sorting

# %%
def is_sorted(arr):
    sorted=True
    for i in range(len(arr)-1):
        if arr[i]>arr[i+1]:
            sorted=False
    return sorted

# %%
arr=[1,2,3,4,5,6]
is_sorted(arr)
# Out:
# True

# %%
arr=[1,2,3,4,8,6]
is_sorted(arr)
# Out:
# False

# %% [markdown]
# # Monkey Sort

# %%
import random

# %%
def monkey_sort(arr):
    while not is_sorted(arr):
        random.shuffle(arr)
        print(arr)
    print(arr)

# %%
a=[12,24,11,56,34,20]
monkey_sort(arr)
# Out:
# [4, 8, 6, 3, 2, 1]
# [4, 1, 3, 8, 2, 6]
# [6, 1, 4, 8, 3, 2]
# [1, 6, 3, 4, 2, 8]
# [1, 6, 4, 2, 3, 8]
# [3, 2, 4, 6, 1, 8]
# [2, 1, 4, 3, 8, 6]
# [8, 2, 6, 4, 3, 1]
# [4, 2, 8, 6, 3, 1]
# [6, 3, 1, 4, 8, 2]
# [6, 4, 8, 1, 3, 2]
# [6, 3, 1, 2, 4, 8]
# [8, 4, 1, 2, 6, 3]
# [8, 1, 2, 6, 4, 3]
# [4, 3, 2, 8, 1, 6]
# [6, 1, 3, 2, 8, 4]
# [2, 8, 3, 4, 1, 6]
# [8, 4, 1, 3, 2, 6]
# [1, 3, 2, 4, 8, 6]
# [6, 8, 3, 2, 4, 1]
# [1, 6, 3, 2, 4, 8]
# [6, 3, 4, 2, 8, 1]
# [2, 4, 1, 6, 3, 8]
# [6, 4, 8, 2, 3, 1]
# [3, 1, 8, 6, 4, 2]
# [2, 3, 1, 6, 4, 8]
# [2, 6, 1, 3, 4, 8]
# [3, 8, 2, 4, 6, 1]
# [8, 3, 6, 2, 1, 4]
# [1, 4, 6, 3, 2, 8]
# [3, 8, 4, 2, 1, 6]
# [6, 3, 1, 2, 4, 8]
# [1, 3, 6, 8, 4, 2]
# [6, 4, 2, 8, 1, 3]
# [4, 8, 3, 2, 6, 1]
# [2, 6, 1, 3, 4, 8]
# [8, 2, 6, 1, 4, 3]
# [8, 6, 4, 2, 3, 1]
# [8, 2, 6, 4, 3, 1]
# [6, 1, 8, 3, 2, 4]
# [3, 1, 8, 4, 2, 6]
# [1, 8, 6, 2, 4, 3]
# [6, 4, 8, 2, 3, 1]
# [1, 6, 2, 3, 8, 4]
# [6, 3, 2, 4, 1, 8]
# [6, 1, 8, 3, 2, 4]
# [6, 3, 8, 2, 1, 4]
# [1, 8, 6, 4, 2, 3]
# [8, 3, 4, 6, 1, 2]
# [4, 1, 6, 3, 8, 2]
# [1, 8, 3, 2, 6, 4]
# [6, 4, 3, 8, 2, 1]
# [8, 6, 1, 3, 4, 2]
# [2, 6, 8, 3, 4, 1]
# [1, 8, 3, 4, 2, 6]
# [6, 8, 2, 3, 1, 4]
# [3, 6, 2, 4, 8, 1]
# [2, 4, 6, 1, 3, 8]
# [6, 3, 4, 1, 8, 2]
# [1, 4, 3, 8, 2, 6]
# [8, 6, 1, 2, 4, 3]
# [3, 6, 8, 1, 4, 2]
# [3, 2, 6, 4, 8, 1]
# [6, 1, 8, 3, 4, 2]
# [1, 2, 3, 8, 4, 6]
# [6, 1, 2, 8, 4, 3]
# [8, 2, 1, 4, 3, 6]
# [3, 1, 4, 2, 6, 8]
# [3, 1, 8, 6, 4, 2]
# [1, 8, 4, 3, 6, 2]
# [8, 1, 4, 2, 6, 3]
# [2, 3, 1, 8, 4, 6]
# [1, 3, 6, 4, 8, 2]
# [1, 3, 8, 6, 4, 2]
# [4, 8, 2, 3, 6, 1]
# [2, 4, 3, 6, 1, 8]
# [3, 2, 6, 4, 1, 8]
# [6, 1, 3, 8, 2, 4]
# [2, 8, 6, 1, 4, 3]
# [1, 4, 3, 2, 8, 6]
# [1, 4, 6, 2, 3, 8]
# [3, 2, 1, 6, 4, 8]
# [4, 6, 2, 1, 3, 8]
# [2, 3, 6, 1, 8, 4]
# [3, 4, 1, 2, 8, 6]
# [1, 6, 2, 8, 4, 3]
# [2, 1, 6, 8, 4, 3]
# [8, 2, 3, 4, 6, 1]
# [2, 8, 6, 3, 4, 1]
# [3, 6, 1, 8, 4, 2]
# [2, 1, 8, 3, 6, 4]
# [1, 4, 2, 8, 3, 6]
# [2, 6, 4, 8, 3, 1]
# [2, 6, 1, 8, 4, 3]
# [2, 3, 8, 1, 4, 6]
# [2, 8, 3, 4, 1, 6]
# [3, 1, 2, 8, 4, 6]
# [8, 2, 6, 1, 3, 4]
# [6, 8, 4, 1, 2, 3]
# [8, 1, 6, 2, 4, 3]
# [1, 8, 6, 3, 4, 2]
# [6, 8, 4, 1, 3, 2]
# [6, 1, 8, 4, 3, 2]
# [2, 6, 3, 4, 1, 8]
# [4, 3, 1, 2, 8, 6]
# [4, 8, 2, 3, 1, 6]
# [6, 3, 1, 2, 8, 4]
# [1, 8, 2, 6, 4, 3]
# [3, 8, 1, 2, 6, 4]
# [3, 8, 6, 4, 2, 1]
# [8, 4, 1, 2, 3, 6]
# [3, 1, 4, 6, 8, 2]
# [6, 3, 1, 4, 8, 2]
# [2, 3, 8, 6, 4, 1]
# [1, 3, 2, 4, 8, 6]
# [1, 6, 2, 8, 3, 4]
# [1, 2, 6, 3, 8, 4]
# [3, 6, 4, 2, 8, 1]
# [4, 2, 1, 3, 8, 6]
# [1, 4, 8, 3, 6, 2]
# [4, 8, 2, 6, 3, 1]
# [4, 1, 8, 3, 2, 6]
# [1, 4, 3, 8, 6, 2]
# [6, 3, 1, 4, 2, 8]
# [1, 4, 6, 3, 8, 2]
# [4, 8, 3, 2, 6, 1]
# [1, 4, 8, 3, 6, 2]
# [1, 2, 8, 3, 6, 4]
# [2, 8, 4, 3, 1, 6]
# [2, 3, 4, 6, 1, 8]
# [1, 2, 8, 6, 3, 4]
# [2, 8, 4, 1, 3, 6]
# [4, 3, 6, 8, 2, 1]
# [8, 1, 3, 6, 2, 4]
# [8, 1, 4, 6, 2, 3]
# [4, 1, 3, 8, 6, 2]
# [2, 4, 6, 3, 8, 1]
# [1, 4, 2, 8, 6, 3]
# [1, 3, 4, 6, 8, 2]
# [1, 3, 6, 2, 4, 8]
# [4, 6, 8, 3, 1, 2]
# [1, 2, 6, 8, 3, 4]
# [3, 4, 6, 1, 8, 2]
# [4, 8, 6, 2, 3, 1]
# [4, 6, 1, 3, 8, 2]
# [8, 4, 1, 6, 3, 2]
# [2, 1, 3, 6, 8, 4]
# [2, 4, 8, 6, 1, 3]
# [2, 3, 6, 8, 1, 4]
# [2, 8, 6, 4, 3, 1]
# [3, 2, 4, 6, 1, 8]
# [1, 4, 3, 6, 8, 2]
# [8, 2, 4, 6, 3, 1]
# [6, 8, 1, 2, 3, 4]
# [8, 1, 4, 3, 6, 2]
# [8, 6, 1, 2, 3, 4]
# [4, 2, 1, 8, 6, 3]
# [6, 4, 1, 2, 3, 8]
# [4, 1, 6, 3, 8, 2]
# [8, 6, 3, 2, 4, 1]
# [1, 6, 3, 8, 4, 2]
# [8, 3, 4, 2, 1, 6]
# [6, 1, 3, 4, 8, 2]
# [4, 6, 3, 8, 2, 1]
# [6, 3, 8, 4, 1, 2]
# [4, 2, 6, 1, 3, 8]
# [4, 1, 6, 2, 3, 8]
# [6, 4, 3, 8, 2, 1]
# [6, 4, 2, 3, 1, 8]
# [8, 3, 2, 1, 4, 6]
# [6, 1, 3, 8, 4, 2]
# [8, 6, 2, 4, 3, 1]
# [2, 6, 4, 1, 8, 3]
# [3, 1, 2, 8, 4, 6]
# [8, 2, 6, 1, 3, 4]
# [2, 1, 6, 4, 8, 3]
# [2, 3, 8, 4, 6, 1]
# [6, 4, 2, 3, 8, 1]
# [1, 2, 4, 8, 3, 6]
# [6, 8, 4, 3, 1, 2]
# [6, 4, 2, 8, 3, 1]
# [3, 2, 4, 6, 8, 1]
# [8, 1, 6, 3, 4, 2]
# [3, 1, 6, 4, 8, 2]
# [1, 6, 8, 2, 3, 4]
# [8, 4, 1, 2, 6, 3]
# [8, 4, 6, 1, 2, 3]
# [4, 8, 1, 6, 2, 3]
# [8, 2, 4, 3, 6, 1]
# [6, 8, 1, 3, 4, 2]
# [8, 4, 1, 6, 3, 2]
# [3, 4, 2, 1, 8, 6]
# [4, 6, 2, 3, 8, 1]
# [3, 4, 8, 1, 2, 6]
# [2, 1, 4, 8, 3, 6]
# [6, 4, 1, 8, 2, 3]
# [3, 1, 2, 8, 4, 6]
# [1, 6, 3, 2, 8, 4]
# [6, 3, 8, 1, 4, 2]
# [3, 1, 4, 6, 2, 8]
# [3, 6, 1, 8, 4, 2]
# [8, 4, 3, 2, 6, 1]
# [6, 3, 4, 1, 2, 8]
# [3, 2, 8, 1, 4, 6]
# [8, 4, 3, 1, 2, 6]
# [8, 3, 1, 6, 2, 4]
# [2, 8, 3, 4, 6, 1]
# [6, 4, 1, 8, 2, 3]
# [2, 3, 8, 6, 1, 4]
# [3, 6, 4, 1, 8, 2]
# [2, 3, 8, 1, 4, 6]
# [3, 2, 4, 1, 6, 8]
# [1, 6, 4, 8, 2, 3]
# [1, 6, 8, 2, 3, 4]
# [4, 6, 1, 8, 2, 3]
# [4, 6, 1, 3, 2, 8]
# [4, 8, 1, 2, 6, 3]
# [4, 2, 3, 6, 8, 1]
# [1, 4, 8, 3, 2, 6]
# [3, 2, 1, 6, 8, 4]
# [3, 2, 4, 8, 1, 6]
# [8, 1, 6, 2, 3, 4]
# [1, 6, 2, 3, 8, 4]
# [2, 8, 6, 4, 3, 1]
# [3, 4, 8, 2, 1, 6]
# [8, 2, 1, 3, 4, 6]
# [8, 6, 2, 3, 1, 4]
# [6, 3, 1, 2, 8, 4]
# [2, 4, 1, 8, 3, 6]
# [6, 4, 2, 3, 1, 8]
# [6, 2, 1, 4, 3, 8]
# [2, 4, 8, 3, 1, 6]
# [4, 6, 8, 1, 3, 2]
# [8, 2, 1, 3, 4, 6]
# [3, 4, 1, 2, 8, 6]
# [6, 1, 8, 3, 2, 4]
# [8, 6, 1, 3, 4, 2]
# [1, 3, 8, 2, 6, 4]
# [4, 2, 1, 8, 3, 6]
# [8, 6, 4, 3, 2, 1]
# [3, 2, 8, 6, 1, 4]
# [4, 8, 3, 6, 1, 2]
# [4, 8, 3, 2, 6, 1]
# [1, 8, 3, 4, 6, 2]
# [8, 3, 2, 6, 1, 4]
# [2, 1, 4, 6, 8, 3]
# [3, 1, 8, 2, 6, 4]
# [3, 4, 2, 1, 8, 6]
# [6, 8, 1, 3, 4, 2]
# [6, 2, 3, 1, 8, 4]
# [1, 3, 4, 2, 8, 6]
# [6, 1, 8, 4, 2, 3]
# [1, 6, 4, 3, 2, 8]
# [1, 8, 6, 3, 2, 4]
# [2, 6, 3, 1, 4, 8]
# [6, 8, 4, 2, 3, 1]
# [2, 3, 4, 6, 1, 8]
# [6, 2, 8, 1, 4, 3]
# [6, 2, 3, 4, 1, 8]
# [6, 4, 3, 8, 2, 1]
# [3, 8, 1, 4, 6, 2]
# [3, 8, 2, 6, 4, 1]
# [8, 4, 1, 3, 6, 2]
# [1, 2, 6, 3, 8, 4]
# [2, 6, 3, 4, 1, 8]
# [8, 6, 1, 3, 4, 2]
# [4, 2, 1, 8, 3, 6]
# [8, 4, 1, 2, 3, 6]
# [1, 4, 3, 2, 6, 8]
# [8, 6, 4, 3, 1, 2]
# [8, 3, 2, 1, 4, 6]
# [1, 6, 4, 8, 2, 3]
# [6, 3, 8, 2, 4, 1]
# [8, 1, 3, 4, 2, 6]
# [1, 3, 2, 6, 8, 4]
# [1, 2, 4, 3, 8, 6]
# [1, 6, 2, 4, 8, 3]
# [1, 3, 8, 2, 4, 6]
# [1, 6, 3, 8, 4, 2]
# [1, 6, 8, 4, 2, 3]
# [1, 4, 6, 2, 8, 3]
# [3, 4, 6, 8, 2, 1]
# [3, 6, 1, 4, 2, 8]
# [6, 4, 3, 8, 2, 1]
# [8, 3, 2, 1, 6, 4]
# [4, 2, 1, 6, 8, 3]
# [2, 6, 1, 3, 4, 8]
# [1, 8, 6, 3, 4, 2]
# [3, 1, 2, 4, 8, 6]
# [8, 4, 3, 6, 1, 2]
# [6, 3, 1, 2, 8, 4]
# [6, 4, 8, 3, 2, 1]
# [4, 2, 6, 1, 3, 8]
# [4, 1, 3, 6, 2, 8]
# [6, 4, 2, 1, 3, 8]
# [4, 3, 6, 2, 8, 1]
# [8, 6, 3, 4, 1, 2]
# [3, 4, 6, 2, 8, 1]
# [4, 6, 3, 8, 2, 1]
# [6, 4, 1, 3, 2, 8]
# [2, 4, 3, 8, 1, 6]
# [3, 8, 6, 2, 1, 4]
# [4, 8, 3, 2, 6, 1]
# [4, 2, 3, 6, 8, 1]
# [4, 6, 3, 8, 1, 2]
# [3, 4, 1, 6, 8, 2]
# [6, 1, 4, 2, 8, 3]
# [4, 3, 1, 8, 2, 6]
# [3, 2, 8, 4, 1, 6]
# [6, 2, 8, 3, 1, 4]
# [4, 2, 8, 6, 3, 1]
# [8, 1, 4, 3, 6, 2]
# [2, 3, 1, 4, 8, 6]
# [8, 4, 3, 6, 1, 2]
# [4, 1, 3, 8, 6, 2]
# [3, 8, 4, 2, 1, 6]
# [1, 4, 2, 3, 8, 6]
# [8, 6, 4, 3, 2, 1]
# [8, 3, 2, 6, 4, 1]
# [8, 4, 3, 2, 6, 1]
# [3, 6, 4, 1, 8, 2]
# [3, 2, 1, 6, 4, 8]
# [8, 2, 6, 1, 4, 3]
# [6, 4, 3, 1, 8, 2]
# [4, 3, 6, 8, 1, 2]
# [2, 3, 6, 8, 4, 1]
# [1, 4, 6, 2, 3, 8]
# [2, 6, 8, 4, 3, 1]
# [4, 6, 1, 8, 2, 3]
# [6, 2, 4, 3, 1, 8]
# [4, 2, 8, 3, 6, 1]
# [2, 6, 8, 1, 4, 3]
# [4, 8, 3, 2, 6, 1]
# [1, 3, 2, 8, 4, 6]
# [6, 4, 1, 8, 2, 3]
# [3, 1, 8, 2, 6, 4]
# [6, 2, 3, 1, 8, 4]
# [2, 8, 4, 6, 3, 1]
# [1, 2, 8, 6, 4, 3]
# [2, 3, 4, 1, 8, 6]
# [4, 3, 6, 1, 2, 8]
# [8, 4, 3, 2, 1, 6]
# [1, 4, 8, 3, 2, 6]
# [8, 3, 1, 2, 6, 4]
# [1, 3, 8, 2, 6, 4]
# [4, 8, 3, 6, 1, 2]
# [2, 1, 6, 4, 8, 3]
# [3, 6, 4, 8, 1, 2]
# [3, 8, 1, 2, 4, 6]
# [2, 3, 8, 1, 6, 4]
# [4, 6, 2, 1, 8, 3]
# [1, 2, 8, 6, 3, 4]
# [4, 8, 2, 3, 6, 1]
# [6, 4, 8, 2, 3, 1]
# [2, 8, 1, 6, 4, 3]
# [1, 8, 6, 3, 4, 2]
# [2, 1, 4, 8, 6, 3]
# [2, 4, 8, 3, 1, 6]
# [2, 8, 4, 1, 6, 3]
# [3, 8, 1, 6, 4, 2]
# [2, 4, 1, 8, 3, 6]
# [1, 8, 2, 6, 3, 4]
# [6, 8, 3, 1, 4, 2]
# [6, 4, 3, 1, 2, 8]
# [8, 2, 3, 6, 4, 1]
# [8, 6, 4, 1, 3, 2]
# [4, 1, 3, 8, 6, 2]
# [1, 6, 4, 3, 2, 8]
# [2, 8, 3, 1, 4, 6]
# [3, 1, 8, 2, 6, 4]
# [8, 6, 2, 1, 3, 4]
# [4, 8, 2, 3, 6, 1]
# [4, 3, 6, 1, 8, 2]
# [2, 3, 8, 6, 4, 1]
# [6, 1, 2, 8, 3, 4]
# [1, 8, 2, 3, 6, 4]
# [1, 2, 4, 6, 3, 8]
# [2, 1, 4, 6, 8, 3]
# [2, 6, 8, 3, 1, 4]
# [1, 8, 2, 4, 3, 6]
# [8, 6, 3, 4, 2, 1]
# [3, 8, 2, 4, 1, 6]
# [6, 3, 1, 2, 8, 4]
# [8, 1, 2, 4, 6, 3]
# [2, 8, 6, 4, 3, 1]
# [3, 8, 1, 6, 4, 2]
# [2, 6, 4, 3, 1, 8]
# [3, 8, 2, 1, 4, 6]
# [6, 4, 1, 3, 2, 8]
# [2, 6, 4, 1, 8, 3]
# [8, 3, 6, 1, 4, 2]
# [8, 4, 6, 2, 3, 1]
# [1, 4, 2, 6, 3, 8]
# [6, 2, 1, 8, 4, 3]
# [2, 4, 8, 6, 3, 1]
# [4, 6, 2, 1, 3, 8]
# [6, 3, 8, 4, 2, 1]
# [3, 6, 8, 4, 2, 1]
# [2, 4, 6, 1, 3, 8]
# [8, 6, 2, 1, 3, 4]
# [3, 1, 4, 8, 6, 2]
# [1, 3, 4, 6, 2, 8]
# [2, 8, 6, 4, 1, 3]
# [1, 6, 4, 3, 8, 2]
# [8, 6, 1, 3, 2, 4]
# [6, 3, 2, 8, 4, 1]
# [3, 1, 8, 4, 2, 6]
# [1, 6, 3, 8, 4, 2]
# [2, 4, 1, 8, 3, 6]
# [4, 1, 2, 3, 8, 6]
# [2, 6, 8, 1, 4, 3]
# [2, 4, 3, 8, 6, 1]
# [1, 6, 8, 3, 2, 4]
# [4, 3, 2, 1, 8, 6]
# [4, 3, 8, 6, 1, 2]
# [4, 6, 2, 3, 8, 1]
# [3, 6, 2, 8, 4, 1]
# [6, 2, 4, 8, 3, 1]
# [4, 6, 2, 3, 1, 8]
# [1, 2, 3, 4, 8, 6]
# [4, 3, 1, 2, 6, 8]
# [1, 4, 2, 6, 8, 3]
# [2, 4, 3, 1, 6, 8]
# [4, 3, 1, 2, 8, 6]
# [8, 2, 4, 6, 1, 3]
# [3, 2, 8, 4, 6, 1]
# [6, 4, 3, 2, 1, 8]
# [1, 8, 2, 6, 4, 3]
# [3, 2, 6, 8, 4, 1]
# [6, 8, 4, 2, 3, 1]
# [3, 2, 6, 1, 4, 8]
# [2, 6, 4, 8, 3, 1]
# [2, 8, 6, 3, 4, 1]
# [2, 4, 3, 1, 6, 8]
# [1, 6, 4, 2, 3, 8]
# [3, 8, 2, 6, 4, 1]
# [8, 3, 6, 1, 4, 2]
# [3, 1, 4, 2, 8, 6]
# [6, 8, 2, 1, 4, 3]
# [2, 4, 6, 1, 3, 8]
# [3, 8, 6, 4, 2, 1]
# [3, 4, 1, 2, 6, 8]
# [2, 4, 1, 6, 3, 8]
# [3, 1, 6, 8, 4, 2]
# [1, 3, 4, 6, 2, 8]
# [1, 8, 3, 4, 6, 2]
# [1, 2, 8, 3, 6, 4]
# [6, 8, 1, 3, 2, 4]
# [2, 3, 8, 6, 1, 4]
# [3, 4, 1, 2, 8, 6]
# [8, 2, 3, 4, 6, 1]
# [6, 8, 3, 2, 1, 4]
# [8, 2, 4, 6, 1, 3]
# [8, 1, 2, 4, 6, 3]
# [1, 2, 8, 6, 4, 3]
# [4, 1, 2, 6, 3, 8]
# [8, 6, 3, 4, 2, 1]
# [4, 2, 1, 8, 3, 6]
# [4, 1, 6, 3, 2, 8]
# [8, 3, 4, 6, 2, 1]
# [8, 4, 3, 6, 1, 2]
# [2, 6, 1, 8, 4, 3]
# [8, 2, 6, 1, 4, 3]
# [4, 3, 2, 8, 1, 6]
# [4, 3, 2, 8, 1, 6]
# [6, 8, 1, 3, 2, 4]
# [1, 3, 4, 8, 6, 2]
# [6, 2, 3, 4, 1, 8]
# [8, 1, 2, 6, 3, 4]
# [4, 3, 6, 2, 1, 8]
# [8, 1, 2, 3, 6, 4]
# [3, 1, 2, 6, 4, 8]
# [3, 6, 8, 1, 2, 4]
# [6, 2, 3, 1, 4, 8]
# [4, 1, 8, 2, 6, 3]
# [2, 1, 6, 4, 3, 8]
# [1, 3, 6, 8, 4, 2]
# [6, 2, 8, 1, 4, 3]
# [6, 3, 2, 8, 4, 1]
# [3, 2, 6, 8, 4, 1]
# [2, 1, 8, 6, 3, 4]
# [6, 8, 2, 1, 3, 4]
# [3, 8, 2, 1, 4, 6]
# [6, 3, 1, 4, 8, 2]
# [3, 2, 1, 6, 8, 4]
# [8, 4, 1, 6, 2, 3]
# [2, 6, 1, 8, 3, 4]
# [4, 8, 3, 6, 2, 1]
# [2, 8, 6, 4, 3, 1]
# [2, 1, 3, 6, 4, 8]
# [3, 1, 8, 2, 4, 6]
# [3, 1, 6, 4, 8, 2]
# [6, 4, 3, 8, 1, 2]
# [2, 4, 8, 6, 1, 3]
# [8, 3, 2, 4, 6, 1]
# [1, 8, 6, 4, 3, 2]
# [3, 2, 1, 4, 8, 6]
# [6, 8, 1, 4, 2, 3]
# [4, 2, 3, 1, 8, 6]
# [8, 3, 6, 2, 1, 4]
# [1, 2, 6, 4, 3, 8]
# [6, 4, 1, 3, 2, 8]
# [6, 3, 8, 2, 1, 4]
# [6, 2, 3, 8, 4, 1]
# [8, 6, 1, 4, 3, 2]
# [6, 8, 1, 2, 3, 4]
# [6, 1, 3, 4, 8, 2]
# [2, 4, 3, 6, 8, 1]
# [8, 6, 3, 4, 2, 1]
# [8, 2, 6, 4, 3, 1]
# [8, 2, 1, 4, 3, 6]
# [4, 1, 6, 2, 3, 8]
# [6, 3, 1, 2, 8, 4]
# [1, 2, 4, 8, 3, 6]
# [8, 4, 6, 3, 2, 1]
# [4, 6, 3, 2, 1, 8]
# [2, 6, 4, 8, 1, 3]
# [1, 6, 2, 3, 8, 4]
# [2, 3, 4, 1, 8, 6]
# [4, 1, 8, 6, 3, 2]
# [3, 6, 4, 1, 2, 8]
# [2, 1, 4, 3, 6, 8]
# [6, 1, 2, 3, 4, 8]
# [1, 6, 3, 2, 4, 8]
# [1, 3, 6, 2, 8, 4]
# [4, 8, 3, 2, 1, 6]
# [3, 6, 8, 4, 2, 1]
# [6, 4, 2, 8, 3, 1]
# [4, 6, 8, 3, 1, 2]
# [6, 3, 4, 2, 1, 8]
# [6, 8, 4, 1, 2, 3]
# [6, 3, 8, 1, 4, 2]
# [3, 6, 1, 2, 4, 8]
# [1, 4, 8, 6, 3, 2]
# [2, 3, 8, 4, 1, 6]
# [1, 8, 4, 2, 6, 3]
# [3, 4, 8, 1, 6, 2]
# [4, 8, 2, 1, 3, 6]
# [1, 2, 3, 8, 4, 6]
# [4, 3, 6, 8, 1, 2]
# [6, 4, 8, 2, 1, 3]
# [4, 2, 1, 8, 3, 6]
# [8, 1, 6, 2, 4, 3]
# [6, 8, 1, 4, 3, 2]
# [3, 2, 1, 6, 8, 4]
# [2, 8, 1, 6, 4, 3]
# [8, 2, 6, 1, 3, 4]
# [8, 6, 3, 4, 1, 2]
# [8, 2, 1, 4, 6, 3]
# [1, 3, 6, 8, 2, 4]
# [1, 8, 6, 4, 3, 2]
# [4, 8, 2, 3, 1, 6]
# [6, 4, 2, 8, 1, 3]
# [1, 2, 6, 3, 8, 4]
# [6, 1, 2, 4, 8, 3]
# [8, 2, 3, 1, 6, 4]
# [2, 3, 4, 8, 6, 1]
# [1, 4, 6, 2, 8, 3]
# [8, 4, 3, 2, 1, 6]
# [1, 4, 8, 6, 3, 2]
# [3, 1, 2, 8, 4, 6]
# [3, 4, 1, 8, 2, 6]
# [6, 8, 3, 2, 1, 4]
# [8, 6, 2, 4, 1, 3]
# [3, 6, 2, 4, 8, 1]
# [2, 1, 6, 8, 4, 3]
# [3, 6, 1, 4, 2, 8]
# [8, 1, 2, 3, 4, 6]
# [2, 1, 6, 8, 4, 3]
# [4, 2, 6, 1, 3, 8]
# [1, 6, 2, 8, 4, 3]
# [8, 3, 2, 6, 1, 4]
# [6, 4, 1, 2, 3, 8]
# [1, 4, 6, 3, 8, 2]
# [8, 1, 4, 3, 2, 6]
# [1, 3, 8, 6, 2, 4]
# [2, 8, 6, 4, 1, 3]
# [3, 1, 8, 4, 6, 2]
# [6, 8, 3, 1, 4, 2]
# [6, 2, 8, 1, 3, 4]
# [1, 2, 4, 8, 6, 3]
# [1, 4, 8, 6, 3, 2]
# [8, 4, 2, 6, 1, 3]
# [4, 3, 8, 6, 2, 1]
# [6, 3, 2, 4, 1, 8]
# [2, 1, 3, 4, 6, 8]
# [1, 6, 2, 4, 8, 3]
# [2, 6, 8, 1, 4, 3]
# [3, 6, 4, 8, 2, 1]
# [2, 4, 3, 6, 1, 8]
# [6, 4, 8, 2, 3, 1]
# [4, 6, 1, 2, 3, 8]
# [6, 2, 8, 3, 1, 4]
# [2, 8, 3, 1, 4, 6]
# [4, 3, 2, 8, 6, 1]
# [2, 3, 1, 6, 8, 4]
# [3, 6, 2, 1, 4, 8]
# [8, 3, 4, 6, 2, 1]
# [3, 4, 8, 2, 1, 6]
# [6, 1, 2, 3, 4, 8]
# [6, 3, 1, 2, 4, 8]
# [1, 2, 4, 8, 6, 3]
# [6, 1, 4, 3, 8, 2]
# [8, 6, 3, 2, 1, 4]
# [8, 1, 6, 4, 2, 3]
# [2, 4, 6, 1, 3, 8]
# [2, 6, 3, 1, 8, 4]
# [4, 1, 6, 8, 3, 2]
# [1, 4, 8, 3, 6, 2]
# [8, 4, 6, 1, 3, 2]
# [3, 2, 4, 8, 6, 1]
# [8, 3, 2, 1, 6, 4]
# [4, 8, 1, 3, 6, 2]
# [3, 6, 2, 1, 4, 8]
# [1, 2, 6, 8, 3, 4]
# [2, 8, 1, 6, 4, 3]
# [8, 6, 2, 3, 1, 4]
# [3, 2, 8, 1, 4, 6]
# [4, 8, 3, 6, 1, 2]
# [1, 6, 4, 8, 2, 3]
# [8, 3, 4, 6, 2, 1]
# [2, 3, 6, 4, 8, 1]
# [1, 4, 8, 3, 6, 2]
# [4, 2, 8, 1, 6, 3]
# [1, 3, 2, 8, 6, 4]
# [6, 2, 3, 1, 8, 4]
# [8, 6, 2, 4, 3, 1]
# [2, 4, 6, 8, 3, 1]
# [6, 8, 4, 1, 3, 2]
# [3, 6, 2, 8, 1, 4]
# [6, 1, 3, 2, 8, 4]
# [2, 1, 4, 3, 6, 8]
# [2, 1, 4, 8, 3, 6]
# [3, 1, 4, 8, 6, 2]
# [6, 3, 8, 1, 4, 2]
# [2, 3, 6, 8, 1, 4]
# [2, 1, 8, 6, 3, 4]
# [8, 4, 3, 2, 1, 6]
# [6, 2, 4, 3, 1, 8]
# [8, 3, 2, 4, 1, 6]
# [2, 1, 3, 4, 6, 8]
# [1, 2, 6, 4, 3, 8]
# [8, 1, 6, 4, 2, 3]
# [8, 1, 3, 6, 2, 4]
# [6, 3, 8, 4, 2, 1]
# [6, 2, 1, 4, 3, 8]
# [1, 2, 6, 3, 4, 8]
# [6, 3, 4, 2, 8, 1]
# [8, 6, 2, 4, 1, 3]
# [3, 8, 1, 6, 2, 4]
# [4, 8, 6, 1, 2, 3]
# [2, 3, 6, 1, 4, 8]
# [2, 1, 4, 6, 8, 3]
# [2, 8, 4, 6, 3, 1]
# [3, 6, 2, 8, 1, 4]
# [1, 6, 8, 3, 4, 2]
# [8, 3, 2, 4, 6, 1]
# [1, 8, 4, 2, 6, 3]
# [4, 1, 3, 6, 2, 8]
# [2, 1, 3, 4, 8, 6]
# [6, 2, 4, 3, 8, 1]
# [2, 8, 6, 4, 1, 3]
# [1, 3, 6, 4, 2, 8]
# [4, 8, 1, 3, 2, 6]
# [6, 2, 1, 4, 8, 3]
# [6, 2, 8, 4, 1, 3]
# [8, 2, 6, 3, 4, 1]
# [8, 2, 3, 6, 4, 1]
# [2, 8, 6, 3, 1, 4]
# [1, 8, 3, 2, 6, 4]
# [1, 2, 8, 3, 6, 4]
# [2, 3, 1, 4, 8, 6]
# [1, 4, 2, 8, 6, 3]
# [8, 3, 4, 1, 2, 6]
# [4, 8, 2, 3, 6, 1]
# [8, 1, 3, 2, 4, 6]
# [8, 2, 3, 1, 4, 6]
# [2, 6, 3, 4, 1, 8]
# [2, 6, 1, 3, 8, 4]
# [3, 4, 1, 6, 2, 8]
# [3, 1, 2, 6, 8, 4]
# [6, 8, 3, 1, 2, 4]
# [4, 8, 1, 2, 3, 6]
# [8, 3, 1, 4, 6, 2]
# [3, 6, 4, 1, 8, 2]
# [4, 3, 2, 1, 6, 8]
# [4, 6, 2, 1, 8, 3]
# [2, 6, 8, 3, 1, 4]
# [4, 2, 8, 3, 1, 6]
# [2, 4, 6, 8, 3, 1]
# [4, 8, 3, 6, 1, 2]
# [8, 4, 6, 1, 3, 2]
# [4, 3, 8, 6, 1, 2]
# [6, 4, 3, 2, 1, 8]
# [3, 1, 6, 4, 2, 8]
# [8, 2, 1, 6, 3, 4]
# [1, 6, 4, 3, 2, 8]
# [1, 3, 8, 6, 4, 2]
# [1, 2, 8, 6, 4, 3]
# [1, 3, 4, 2, 8, 6]
# [8, 2, 4, 1, 3, 6]
# [3, 1, 8, 6, 4, 2]
# [4, 8, 3, 1, 2, 6]
# [4, 8, 6, 2, 1, 3]
# [4, 1, 3, 2, 6, 8]
# [1, 8, 2, 4, 6, 3]
# [6, 1, 3, 4, 8, 2]
# [8, 3, 6, 1, 4, 2]
# [8, 1, 3, 4, 6, 2]
# [6, 3, 4, 8, 2, 1]
# [2, 1, 8, 4, 3, 6]
# [6, 3, 4, 8, 2, 1]
# [2, 4, 3, 8, 6, 1]
# [3, 2, 1, 6, 8, 4]
# [6, 2, 8, 4, 1, 3]
# [4, 1, 2, 6, 3, 8]
# [4, 1, 6, 8, 3, 2]
# [3, 4, 8, 1, 2, 6]
# [6, 8, 4, 3, 1, 2]
# [2, 4, 1, 3, 6, 8]
# [3, 1, 8, 2, 6, 4]
# [2, 8, 6, 1, 4, 3]
# [3, 4, 8, 6, 2, 1]
# [4, 1, 6, 8, 2, 3]
# [8, 4, 6, 1, 2, 3]
# [6, 2, 4, 3, 8, 1]
# [2, 4, 8, 3, 1, 6]
# [4, 6, 2, 3, 8, 1]
# [8, 3, 2, 6, 4, 1]
# [2, 6, 8, 1, 4, 3]
# [4, 3, 6, 2, 8, 1]
# [2, 6, 4, 1, 8, 3]
# [1, 4, 8, 3, 6, 2]
# [4, 1, 2, 3, 6, 8]
# [6, 1, 2, 8, 3, 4]
# [4, 6, 2, 8, 1, 3]
# [1, 6, 3, 8, 4, 2]
# [1, 3, 8, 2, 4, 6]
# [4, 6, 2, 8, 3, 1]
# [6, 3, 4, 8, 1, 2]
# [8, 2, 4, 1, 6, 3]
# [1, 8, 2, 3, 4, 6]
# [6, 1, 2, 4, 3, 8]
# [1, 8, 3, 2, 6, 4]
# [2, 4, 6, 8, 1, 3]
# [3, 6, 1, 8, 2, 4]
# [1, 8, 3, 2, 6, 4]
# [8, 2, 1, 6, 4, 3]
# [3, 8, 1, 4, 2, 6]
# [4, 6, 3, 8, 1, 2]
# [2, 8, 6, 3, 1, 4]
# [3, 2, 6, 8, 1, 4]
# [8, 2, 4, 3, 1, 6]
# [6, 8, 1, 2, 4, 3]
# [4, 6, 3, 2, 8, 1]
# [6, 8, 4, 1, 2, 3]
# [4, 3, 2, 1, 6, 8]
# [1, 4, 2, 3, 6, 8]
# [8, 4, 3, 6, 2, 1]
# [3, 2, 1, 8, 6, 4]
# [8, 6, 2, 4, 3, 1]
# [1, 2, 6, 3, 4, 8]
# [2, 4, 8, 1, 6, 3]
# [4, 3, 2, 1, 6, 8]
# [3, 4, 8, 6, 1, 2]
# [1, 6, 2, 3, 8, 4]
# [1, 8, 3, 4, 6, 2]
# [8, 4, 2, 6, 1, 3]
# [6, 2, 8, 4, 3, 1]
# [6, 1, 3, 2, 8, 4]
# [1, 2, 8, 4, 3, 6]
# [4, 8, 1, 3, 6, 2]
# [4, 6, 3, 2, 8, 1]
# [1, 2, 6, 3, 8, 4]
# [8, 6, 3, 1, 2, 4]
# [8, 1, 6, 2, 3, 4]
# [1, 2, 4, 3, 6, 8]
# [6, 1, 4, 2, 3, 8]
# [4, 2, 8, 1, 3, 6]
# [8, 2, 1, 6, 4, 3]
# [4, 1, 6, 3, 8, 2]
# [2, 4, 6, 8, 3, 1]
# [4, 1, 8, 2, 6, 3]
# [4, 3, 1, 8, 2, 6]
# [4, 2, 3, 1, 8, 6]
# [3, 4, 6, 1, 2, 8]
# [8, 2, 3, 6, 1, 4]
# [4, 2, 8, 6, 1, 3]
# [1, 6, 4, 8, 3, 2]
# [4, 8, 6, 1, 3, 2]
# [3, 8, 2, 6, 4, 1]
# [8, 1, 2, 6, 3, 4]
# [3, 2, 1, 6, 4, 8]
# [3, 4, 8, 2, 6, 1]
# [1, 3, 4, 8, 2, 6]
# [8, 4, 1, 2, 6, 3]
# [4, 1, 6, 2, 8, 3]
# [1, 8, 4, 2, 3, 6]
# [4, 6, 2, 1, 3, 8]
# [1, 4, 2, 8, 6, 3]
# [2, 8, 6, 3, 1, 4]
# [1, 2, 4, 6, 3, 8]
# [4, 1, 6, 8, 3, 2]
# [2, 3, 8, 1, 4, 6]
# [4, 1, 8, 6, 2, 3]
# [8, 3, 4, 1, 6, 2]
# [4, 1, 8, 2, 3, 6]
# [2, 6, 4, 8, 3, 1]
# [6, 3, 2, 8, 1, 4]
# [6, 4, 3, 2, 1, 8]
# [3, 1, 4, 6, 8, 2]
# [4, 1, 2, 8, 3, 6]
# [4, 6, 8, 1, 3, 2]
# [8, 1, 2, 6, 4, 3]
# [2, 3, 8, 1, 6, 4]
# [3, 8, 1, 6, 2, 4]
# [8, 4, 1, 2, 3, 6]
# [2, 8, 4, 1, 3, 6]
# [4, 2, 1, 6, 3, 8]
# [6, 2, 8, 1, 3, 4]
# [6, 3, 8, 4, 1, 2]
# [2, 4, 6, 3, 8, 1]
# [3, 8, 6, 2, 1, 4]
# [6, 8, 3, 2, 4, 1]
# [2, 3, 6, 1, 4, 8]
# [2, 8, 6, 1, 4, 3]
# [8, 1, 6, 2, 3, 4]
# [4, 1, 3, 6, 8, 2]
# [1, 8, 6, 4, 2, 3]
# [1, 8, 3, 2, 4, 6]
# [4, 3, 2, 6, 1, 8]
# [1, 2, 8, 3, 6, 4]
# [3, 6, 2, 4, 8, 1]
# [3, 4, 1, 8, 2, 6]
# [3, 8, 2, 6, 1, 4]
# [4, 6, 1, 8, 3, 2]
# [2, 6, 1, 8, 4, 3]
# [2, 4, 3, 8, 6, 1]
# [2, 8, 1, 4, 6, 3]
# [1, 8, 6, 2, 4, 3]
# [4, 2, 1, 3, 8, 6]
# [3, 4, 6, 2, 8, 1]
# [4, 8, 6, 1, 2, 3]
# [6, 8, 2, 1, 3, 4]
# [3, 6, 2, 8, 4, 1]
# [8, 2, 3, 6, 4, 1]
# [4, 2, 3, 8, 1, 6]
# [2, 4, 8, 1, 3, 6]
# [1, 6, 8, 2, 3, 4]
# [2, 8, 6, 4, 3, 1]
# [8, 3, 1, 6, 4, 2]
# [1, 3, 8, 4, 2, 6]
# [1, 4, 2, 8, 3, 6]
# [3, 4, 8, 6, 2, 1]
# [4, 8, 6, 1, 3, 2]
# [8, 3, 2, 1, 4, 6]
# [2, 6, 4, 1, 8, 3]
# [8, 3, 2, 4, 6, 1]
# [6, 2, 8, 1, 4, 3]
# [1, 6, 3, 2, 4, 8]
# [3, 2, 6, 1, 4, 8]
# [4, 8, 6, 1, 3, 2]
# [2, 4, 8, 1, 3, 6]
# [4, 6, 3, 1, 8, 2]
# [1, 2, 4, 3, 6, 8]
# [4, 2, 8, 6, 3, 1]
# [1, 8, 6, 4, 3, 2]
# [4, 1, 6, 3, 8, 2]
# [8, 4, 6, 1, 3, 2]
# [2, 1, 3, 6, 8, 4]
# [8, 2, 6, 4, 1, 3]
# [3, 8, 1, 2, 4, 6]
# [1, 6, 3, 8, 4, 2]
# [1, 6, 3, 2, 8, 4]
# [2, 8, 3, 4, 1, 6]
# [6, 2, 1, 3, 4, 8]
# [6, 4, 3, 2, 8, 1]
# [8, 4, 6, 2, 1, 3]
# [1, 2, 8, 3, 4, 6]
# [6, 2, 4, 1, 8, 3]
# [1, 2, 8, 4, 3, 6]
# [1, 4, 3, 8, 2, 6]
# [3, 2, 8, 6, 4, 1]
# [2, 1, 8, 3, 4, 6]
# [6, 8, 1, 3, 4, 2]
# [6, 4, 1, 3, 2, 8]
# [4, 1, 2, 8, 3, 6]
# [3, 8, 6, 1, 4, 2]
# [2, 3, 8, 1, 4, 6]
# [6, 8, 2, 1, 4, 3]
# [4, 6, 2, 3, 1, 8]
# [8, 6, 1, 2, 4, 3]
# [8, 6, 1, 2, 3, 4]
# [6, 1, 8, 3, 4, 2]
# [6, 4, 1, 8, 2, 3]
# [8, 3, 2, 4, 1, 6]
# [1, 6, 2, 4, 3, 8]
# [3, 6, 8, 4, 2, 1]
# [8, 3, 2, 4, 6, 1]
# [2, 6, 3, 8, 4, 1]
# [8, 4, 3, 1, 6, 2]
# [1, 8, 2, 4, 6, 3]
# [6, 1, 4, 3, 2, 8]
# [1, 8, 2, 6, 4, 3]
# [4, 8, 6, 1, 3, 2]
# [1, 3, 6, 4, 2, 8]
# [8, 6, 1, 3, 2, 4]
# [2, 3, 1, 4, 6, 8]
# [8, 3, 4, 2, 1, 6]
# [3, 6, 8, 4, 2, 1]
# [1, 8, 6, 4, 2, 3]
# [1, 2, 4, 8, 6, 3]
# [2, 3, 1, 6, 8, 4]
# [3, 1, 2, 6, 8, 4]
# [1, 6, 2, 4, 3, 8]
# [8, 3, 4, 2, 6, 1]
# [6, 4, 8, 1, 3, 2]
# [1, 8, 6, 4, 2, 3]
# [3, 6, 4, 2, 8, 1]
# [3, 1, 6, 2, 4, 8]
# [1, 4, 6, 3, 8, 2]
# [1, 2, 4, 8, 6, 3]
# [6, 1, 8, 3, 4, 2]
# [3, 4, 8, 6, 2, 1]
# [2, 4, 8, 3, 6, 1]
# [1, 8, 4, 3, 2, 6]
# [1, 6, 4, 3, 8, 2]
# [2, 4, 6, 8, 3, 1]
# [2, 3, 1, 4, 8, 6]
# [8, 2, 1, 4, 3, 6]
# [6, 8, 4, 1, 3, 2]
# [4, 6, 2, 1, 3, 8]
# [1, 2, 6, 4, 3, 8]
# [8, 2, 3, 6, 4, 1]
# [8, 4, 3, 1, 6, 2]
# [8, 6, 4, 2, 3, 1]
# [6, 8, 3, 1, 4, 2]
# [2, 3, 6, 8, 1, 4]
# [2, 1, 4, 3, 6, 8]
# [1, 3, 4, 8, 6, 2]
# [3, 6, 4, 8, 2, 1]
# [1, 3, 2, 4, 8, 6]
# [3, 2, 6, 1, 8, 4]
# [6, 2, 4, 1, 3, 8]
# [3, 6, 8, 2, 4, 1]
# [2, 6, 4, 8, 1, 3]
# [6, 1, 3, 8, 4, 2]
# [8, 6, 1, 2, 3, 4]
# [8, 3, 2, 4, 6, 1]
# [2, 6, 3, 1, 8, 4]
# [4, 8, 2, 3, 1, 6]
# [3, 1, 6, 2, 8, 4]
# [8, 2, 4, 3, 1, 6]
# [2, 3, 6, 8, 1, 4]
# [1, 4, 2, 6, 8, 3]
# [3, 4, 8, 2, 6, 1]
# [8, 2, 6, 4, 1, 3]
# [8, 1, 2, 4, 3, 6]
# [4, 2, 3, 6, 1, 8]
# [3, 2, 4, 8, 6, 1]
# [1, 2, 8, 4, 6, 3]
# [3, 4, 6, 2, 8, 1]
# [6, 3, 1, 2, 8, 4]
# [2, 4, 8, 6, 1, 3]
# [6, 8, 1, 4, 3, 2]
# [4, 2, 1, 3, 6, 8]
# [6, 2, 3, 4, 8, 1]
# [4, 6, 3, 2, 1, 8]
# [2, 4, 3, 6, 8, 1]
# [4, 2, 3, 8, 6, 1]
# [3, 2, 4, 8, 6, 1]
# [1, 2, 4, 6, 8, 3]
# [6, 1, 3, 2, 4, 8]
# [1, 2, 8, 3, 4, 6]
# [8, 2, 4, 6, 1, 3]
# [1, 8, 4, 6, 3, 2]
# [6, 3, 2, 1, 4, 8]
# [2, 6, 1, 4, 3, 8]
# [8, 3, 4, 1, 6, 2]
# [4, 2, 8, 6, 3, 1]
# [4, 6, 1, 8, 3, 2]
# [6, 4, 2, 1, 8, 3]
# [2, 8, 4, 3, 6, 1]
# [4, 8, 1, 6, 2, 3]
# [8, 1, 6, 4, 3, 2]
# [6, 2, 3, 1, 8, 4]
# [6, 4, 3, 1, 2, 8]
# [3, 1, 8, 2, 4, 6]
# [1, 8, 6, 3, 2, 4]
# [6, 1, 4, 2, 3, 8]
# [8, 2, 1, 3, 4, 6]
# [4, 8, 6, 1, 2, 3]
# [1, 4, 3, 6, 8, 2]
# [6, 4, 1, 2, 8, 3]
# [8, 2, 4, 6, 1, 3]
# [3, 6, 4, 1, 8, 2]
# [2, 1, 3, 8, 6, 4]
# [1, 2, 6, 8, 3, 4]
# [3, 8, 2, 6, 4, 1]
# [8, 6, 1, 3, 2, 4]
# [6, 8, 3, 1, 4, 2]
# [3, 8, 1, 6, 2, 4]
# [4, 1, 2, 6, 8, 3]
# [1, 2, 6, 8, 3, 4]
# [2, 1, 3, 6, 8, 4]
# [3, 6, 8, 1, 2, 4]
# [1, 4, 3, 6, 2, 8]
# [6, 8, 2, 1, 3, 4]
# [1, 8, 3, 2, 4, 6]
# [4, 2, 8, 6, 3, 1]
# [6, 3, 8, 1, 4, 2]
# [2, 3, 6, 1, 8, 4]
# [2, 4, 8, 1, 3, 6]
# [4, 1, 6, 3, 2, 8]
# [8, 4, 2, 3, 6, 1]
# [6, 1, 8, 3, 2, 4]
# [4, 8, 3, 1, 6, 2]
# [8, 4, 1, 3, 6, 2]
# [1, 8, 3, 6, 4, 2]
# [3, 6, 2, 8, 1, 4]
# [2, 4, 8, 3, 6, 1]
# [4, 3, 2, 1, 6, 8]
# [8, 4, 3, 1, 6, 2]
# [1, 4, 8, 6, 3, 2]
# [2, 4, 6, 8, 1, 3]
# [6, 8, 1, 4, 3, 2]
# [6, 4, 3, 1, 8, 2]
# [6, 4, 8, 1, 3, 2]
# [6, 4, 8, 3, 1, 2]
# [1, 3, 8, 2, 6, 4]
# [1, 3, 2, 4, 6, 8]
# [8, 3, 6, 2, 1, 4]
# [3, 4, 1, 6, 2, 8]
# [2, 6, 3, 8, 4, 1]
# [2, 1, 4, 6, 3, 8]
# [4, 1, 8, 2, 6, 3]
# [6, 3, 8, 4, 1, 2]
# [6, 3, 2, 4, 8, 1]
# [1, 4, 8, 3, 2, 6]
# [2, 1, 3, 6, 8, 4]
# [2, 6, 4, 8, 1, 3]
# [2, 8, 1, 3, 4, 6]
# [6, 1, 4, 2, 8, 3]
# [8, 1, 4, 3, 2, 6]
# [8, 2, 3, 4, 1, 6]
# [2, 4, 8, 1, 3, 6]
# [8, 3, 6, 2, 1, 4]
# [3, 8, 4, 1, 6, 2]
# [1, 4, 6, 3, 8, 2]
# [4, 2, 3, 8, 6, 1]
# [2, 8, 1, 6, 3, 4]
# [6, 3, 2, 1, 4, 8]
# [1, 4, 3, 2, 6, 8]
# [1, 2, 8, 6, 4, 3]
# [1, 2, 3, 4, 6, 8]
# [1, 2, 3, 4, 6, 8]

# %% [markdown]
# # Bubble sort

# %%
def bubble_sort(arr):
    for i in range(len(arr)-1):
        for j in range(len(arr)-1-i):
            if arr[j]>arr[j+1]:
                arr[j],arr[j+1]=arr[j+1],arr[j]
    return arr

# %%
arr=[1,7,9,4,6,2]
bubble_sort(arr)
# Out:
# [1, 2, 4, 6, 7, 9]

# %%
def insertion_sort(arr):
    for i in range(1,len(arr)):
        key=arr[i]
        j=i-1
        while j>=0 and key <arr[j]:
            arr[j+1]=arr[j]
            j-=1
            arr[j+1]=key
    return arr

# %%
arr=[1,7,9,4,6,2]
insertion_sort(arr)
# Out:
# [1, 2, 4, 6, 7, 9]

# %% [markdown]
# # Selection Sort

# %%
def selection_sort(arr):
    for i in range(len(arr)-1):
        print(i+1,'pass',end=" ")
        min=i
        print("current min is ",arr[min])
        for j in range(i+1,len(arr)):
            print("current item under observation:",arr[j])
            if arr[j]<arr[min]:
                print('current item less than min')
                min=j
                print("now the min has become",arr[min])
        arr[i],arr[min]=arr[min],arr[i]
    return arr

# %%
arr=[1,7,9,4,6,2]
selection_sort(arr)
# Out:
# 1 pass current min is  1
# current item under observation: 7
# current item under observation: 9
# current item under observation: 4
# current item under observation: 6
# current item under observation: 2
# 2 pass current min is  7
# current item under observation: 9
# current item under observation: 4
# current item less than min
# now the min has become 4
# current item under observation: 6
# current item under observation: 2
# current item less than min
# now the min has become 2
# 3 pass current min is  9
# current item under observation: 4
# current item less than min
# now the min has become 4
# current item under observation: 6
# current item under observation: 7
# 4 pass current min is  9
# current item under observation: 6
# current item less than min
# now the min has become 6
# current item under observation: 7
# 5 pass current min is  9
# current item under observation: 7
# current item less than min
# now the min has become 7
# [1, 2, 4, 6, 7, 9]

# %% [markdown]
# # Merge Sort

# %%
def merge_sorted(arr1,arr2):
    i=j=0
    merged=[]
    while i<len(arr1) and j<len(arr2):
        if arr1[i]<arr2[j]:
            merged.append(arr1[i])
            i+=1
        else:
            merged.append(arr2[j])
            j+=1
    while i<len(arr1):
        merged.append(arr1[i])
        i+=1
    while j<len(arr2):
        merged.append(arr2[j])
        j+=1
    return merged

# %%
arr1=[1,3,6]
arr2=[2,4,5,7,8]
merge_sorted(arr1,arr2)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
def merge_sort(arr):
    if len(arr)==1:
        return arr
    mid=len(arr)//2
    left=arr[:mid]
    right=arr[mid:]
    left=merge_sort(left)
    right=merge_sort(right)
    
    return merge_sorted(left,right)

# %%
arr=[1,7,8,3,0,2,6]
merge_sort(arr)
# Out:
# [0, 1, 2, 3, 6, 7, 8]

# %% [markdown]
# # Quick Sort

# %%
def partition(array,low,high):
    pivot=array[high]
    i=low-1
    for j in range(low,high):
        if array[j]<=pivot:
            i=i+1
            array[i],array[j]=array[j],array[i] 
    array[i+1],array[high]=array[high],array[i+1]
    return i+1

# %%
def quick_sort(array,low,high):
    if low<high:
        pi=partition(array,low,high)
        quick_sort(array,low,pi-1)
        quick_sort(array,pi+1,high)

# %%
arr=[1,7,8,3,0,2,6]
size=len(arr)
(quick_sort(arr,0,size-1))
print(arr)
# Out:
# [0, 1, 2, 3, 6, 7, 8]

# %% [markdown]
# # Tree

# %% [markdown]
# ### Binary Search Tree

# %%
class Node:
    def __init__(self,value):
        self.left=None
        self.data=value
        self.right=None
        
class Tree:
    def createNode(self,data):
        return Node(data)
    def insert(self,node,data):
        if node is None:
            return self.createNode(data)
        if data<node.data:
            node.left=self.insert(node.left,data)
        else:
            node.right=self.insert(node.right,data)
        return node
    
    def traverse_Inorder(self,root):
        if root is not None:
            self.traverse_Inorder(root.left)
            print(root.data)
            self.traverse_Inorder(root.right)
            
    def traverse_Preorder(self,root):
        if root is not None:
            print(root.data)
            self.traverse_Preorder(root.left)
            self.traverse_Preorder(root.right)        
    def traverse_Postorder(self,root):
        if root is not None:
            self.traverse_Postorder(root.left)
            self.traverse_Postorder(root.right)  
            print(root.data)

    def height(self,root):
        if root is None:
            return -1
        return max(self.height(root.left),self.height(root.right))+1
        
#Driver Code
tree=Tree()
root=tree.createNode(5)
print(root.data)
tree.insert(root,2)
tree.insert(root,10)
tree.insert(root,7)
tree.insert(root,15)
tree.insert(root,12)
tree.insert(root,20)
tree.insert(root,30)
tree.insert(root,6)
tree.insert(root,8)
print('Inorder--->')
tree.traverse_Inorder(root)
print('Preorder--->')
tree.traverse_Preorder(root)
print('Postorder--->')
tree.traverse_Postorder(root)
print('Height')
print(tree.height(root))
# Out:
# 5
# Inorder--->
# 2
# 5
# 6
# 7
# 8
# 10
# 12
# 15
# 20
# 30
# Preorder--->
# 5
# 2
# 10
# 7
# 6
# 8
# 15
# 12
# 20
# 30
# Postorder--->
# 2
# 6
# 8
# 7
# 12
# 30
# 20
# 15
# 10
# 5
# Height
# 4
